# %%
from IPython.display import HTML
from farm_files import visualization as visualization
# Out:
# C:\Users\Jon Andre\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
test = visualization('Antiepileptika')

# %%
test.part1(age_start=20, region = 'Østfold', period_start = 2000, period_end = 2025)

# %%
test.individual('Valproat')

# %%
test.individual('Valproat', gender = 'Mann')

# %%
test.recommended(ikke_anbefalt = ['Valproat'], period_start = 2004, period_end = 2018)

# %%
test.recommended(ikke_anbefalt = ['Valproat'], period_start = 2004, period_end = 2018, region = 'Oslo')

# %%
test.cake()

# %%
test.cake(year=2060)

# %%
HTML(test.individual_time('Valproat', ratio = True))

# %%
test.part3(prevalens = 2.5, gender = 'Kvinne', age_start = 15, age_end = 49, period_start = 2004, period_end = 2018)
