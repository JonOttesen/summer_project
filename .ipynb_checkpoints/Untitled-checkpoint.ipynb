# %%
from farm_files import visualization as visualization

# %%
test = visualization('R03A')
test1 = visualization('Antiepileptika')

# %%
test1.individual('Valproat', period_start = 2004, period_end = 2035, region = 'Hele landet', age_start=19, age_end=40)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-d62fb92c009a> in <module>()
# ----> 1 test1.individual('Volparat', period_start = 2004, period_end = 2035, region = 'Hele landet')
#
# ~\Python\summer_project\farm_files.py in individual(self, drug, gender, region, age_start, age_end, period_start, period_end)
#     246
#     247         age_indexes = self.age_parameters(age_start, age_end)
# --> 248         med_index = self.drugs.index(drug)
#     249         med_type_index = self.drugs.index(self.folder_name)
#     250
#
# ValueError: 'Volparat' is not in list

# %%
test.part1()
# Out:
# C:\Users\Jon Andre\Python\summer_project\farm_files.py:200: RuntimeWarning: divide by zero encountered in log
#   func = self.curve_fitting(np.log(data[i]))

# %%
test1 = visualization('Antiepileptika')

# %%
test.part1()
# Out:
# C:\Users\Jon Andre\Python\summer_project\farm_files.py:200: RuntimeWarning: divide by zero encountered in log
#   func = self.curve_fitting(np.log(data[i]))
